# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading image

# %%
im = plt.imread(r'../images/grayscale/cherry-laithang.jpg')

# %%
im.shape
# Out:
# (4896, 3264, 3)

# %%
type(im)
# Out:
# numpy.ndarray

# %%
im.dtype
# Out:
# dtype('uint8')

# %%
im.shape
# Out:
# (4896, 3264, 3)

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16, 9))
# fig, axs = plt.subplots(1,3)
plt.subplots_adjust(wspace=0.5)

axs[0].imshow(im[:,:,0],cmap='gray')
axs[1].imshow(im[:,:,1],cmap='gray')
axs[2].imshow(im[:,:,1],cmap='gray')

# %%
im = im[:,:,0] # converting it to 2d grayscale image

# %%
im.shape
# Out:
# (4896, 3264)

# %%
im[1000:2000,2000:3000]
# Out:
# array([[ 28,  46,  56, ..., 145, 144, 147],
#        [ 30,  47,  55, ..., 147, 146, 148],
#        [ 32,  47,  53, ..., 147, 145, 148],
#        ...,
#        [198, 200, 203, ..., 192, 193, 194],
#        [200, 201, 203, ..., 192, 193, 194],
#        [202, 202, 203, ..., 192, 193, 194]], dtype=uint8)

# %%
plt.imshow(im[2200:2500,1700:2300],cmap='gray')

# %%
im[2200:2500,1700:2300] = 255
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 im[2200:2500,1700:2300] = 255
#
# ValueError: assignment destination is read-only

# %%
im2 = im.copy()

# %%
im2[2200:2500,1700:2300] = 0

# %%
plt.imshow(im2,cmap='gray')

# %%
plt.imshow(im2[2300:2600,1000:1500],cmap='gray')

# %%
im2[2300:2600,1000:1500] = 0

# %%
plt.imshow(im2,cmap='gray')

# %%
plt.imsave(fname='../images/output/cherry-laithang.jpg',arr=im2,cmap='gray')
