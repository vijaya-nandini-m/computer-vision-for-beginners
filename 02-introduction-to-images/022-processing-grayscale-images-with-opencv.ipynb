# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r'../images/grayscale/cherry-laithang.jpg',cv2.IMREAD_GRAYSCALE)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (4896, 3264)

# %% [markdown]
# ## Not sure about the reason for this error. Kernel dies when below cell is run.

# %%
cv2.imshow('Gray',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.imshow(img,cmap='gray')

# %%
img[2200:2500,1700:2300] = 0 
img[2300:2600,1000:1500] = 0

# %%
plt.imshow(img,cmap='gray')

# %%
cv2.imwrite('../images/output/opencv-cherry-laithang.jpg',img)
# Out:
# True
